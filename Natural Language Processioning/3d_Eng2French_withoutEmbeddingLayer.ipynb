# %%
import pandas as pd
import numpy as np
import string,re
from string import digits



from keras.layers import *
from keras.models import *
from keras.utils import *
from keras.initializers import *
import tensorflow as tf
# Out:
# Using TensorFlow backend.
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/cit/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data_path = '/home/cit/Downloads/fra.txt'

# %%
# Vectorize the data.
num_samples = 10000
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 16
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 64  # Latent dimensionality of the encoding space.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
#encorder_embedding = Embedding(len(en_token_to_int), hidden_size,name = 'enc_emb') (encorder_input)
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 71)     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 93)     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 64), (None,  34816       input_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 64), ( 40448       input_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 93)     6045        lstm_2[0][0]
# ==================================================================================================
# Total params: 81,309
# Trainable params: 81,309
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Run training
from keras.optimizers import * 
model.compile(optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999, decay=0.001), loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs, 
          validation_split=0.2)
# Out:
# WARNING:tensorflow:From /home/cit/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/cit/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.8329 - val_loss: 0.7795
# Epoch 2/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.6205 - val_loss: 0.7109
# Epoch 3/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.5698 - val_loss: 0.6742
# Epoch 4/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.5379 - val_loss: 0.6406
# Epoch 5/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.5137 - val_loss: 0.6197
# Epoch 6/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4937 - val_loss: 0.6043
# Epoch 7/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4778 - val_loss: 0.5952
# Epoch 8/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4657 - val_loss: 0.5804
# Epoch 9/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4559 - val_loss: 0.5752
# Epoch 10/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4461 - val_loss: 0.5642
# Epoch 11/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4384 - val_loss: 0.5595
# Epoch 12/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4310 - val_loss: 0.5523
# Epoch 13/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4250 - val_loss: 0.5487
# Epoch 14/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4199 - val_loss: 0.5438
# Epoch 15/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4144 - val_loss: 0.5413
# Epoch 16/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4098 - val_loss: 0.5365
# Epoch 17/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4057 - val_loss: 0.5333
# Epoch 18/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.4016 - val_loss: 0.5311
# Epoch 19/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3979 - val_loss: 0.5289
# Epoch 20/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3949 - val_loss: 0.5269
# Epoch 21/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3916 - val_loss: 0.5252
# Epoch 22/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3891 - val_loss: 0.5221
# Epoch 23/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3857 - val_loss: 0.5204
# Epoch 24/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3833 - val_loss: 0.5192
# Epoch 25/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3806 - val_loss: 0.5181
# Epoch 26/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3783 - val_loss: 0.5158
# Epoch 27/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3759 - val_loss: 0.5155
# Epoch 28/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3737 - val_loss: 0.5155
# Epoch 29/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3717 - val_loss: 0.5135
# Epoch 30/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3694 - val_loss: 0.5129
# Epoch 31/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3676 - val_loss: 0.5109
# Epoch 32/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3656 - val_loss: 0.5112
# Epoch 33/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3639 - val_loss: 0.5107
# Epoch 34/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3623 - val_loss: 0.5107
# Epoch 35/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3605 - val_loss: 0.5087
# Epoch 36/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3591 - val_loss: 0.5086
# Epoch 37/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3573 - val_loss: 0.5076
# Epoch 38/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3558 - val_loss: 0.5073
# Epoch 39/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3542 - val_loss: 0.5074
# Epoch 40/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3528 - val_loss: 0.5068
# Epoch 41/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3515 - val_loss: 0.5066
# Epoch 42/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3502 - val_loss: 0.5053
# Epoch 43/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3489 - val_loss: 0.5060
# Epoch 44/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3476 - val_loss: 0.5053
# Epoch 45/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3463 - val_loss: 0.5053
# Epoch 46/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3450 - val_loss: 0.5047
# Epoch 47/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3437 - val_loss: 0.5028
# Epoch 48/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3426 - val_loss: 0.5056
# Epoch 49/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3416 - val_loss: 0.5049
# Epoch 50/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3404 - val_loss: 0.5047
# Epoch 51/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3395 - val_loss: 0.5042
# Epoch 52/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3384 - val_loss: 0.5038
# Epoch 53/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3371 - val_loss: 0.5036
# Epoch 54/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3360 - val_loss: 0.5040
# Epoch 55/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3350 - val_loss: 0.5026
# Epoch 56/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3341 - val_loss: 0.5039
# Epoch 57/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3331 - val_loss: 0.5027
# Epoch 58/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3322 - val_loss: 0.5028
# Epoch 59/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3310 - val_loss: 0.5024
# Epoch 60/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3302 - val_loss: 0.5034
# Epoch 61/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3293 - val_loss: 0.5025
# Epoch 62/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3284 - val_loss: 0.5036
# Epoch 63/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3275 - val_loss: 0.5021
# Epoch 64/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3268 - val_loss: 0.5020
# Epoch 65/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3259 - val_loss: 0.5024
# Epoch 66/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3249 - val_loss: 0.5029
# Epoch 67/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3242 - val_loss: 0.5027
# Epoch 68/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3235 - val_loss: 0.5025
# Epoch 69/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3227 - val_loss: 0.5041
# Epoch 70/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3217 - val_loss: 0.5030
# Epoch 71/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3212 - val_loss: 0.5028
# Epoch 72/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3205 - val_loss: 0.5038
# Epoch 73/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3199 - val_loss: 0.5033
# Epoch 74/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3190 - val_loss: 0.5037
# Epoch 75/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3184 - val_loss: 0.5035
# Epoch 76/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3176 - val_loss: 0.5046
# Epoch 77/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3171 - val_loss: 0.5034
# Epoch 78/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3163 - val_loss: 0.5034
# Epoch 79/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3158 - val_loss: 0.5057
# Epoch 80/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3150 - val_loss: 0.5035
# Epoch 81/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3145 - val_loss: 0.5045
# Epoch 82/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3137 - val_loss: 0.5040
# Epoch 83/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3133 - val_loss: 0.5043
# Epoch 84/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3127 - val_loss: 0.5055
# Epoch 85/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3122 - val_loss: 0.5061
# Epoch 86/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3115 - val_loss: 0.5045
# Epoch 87/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3108 - val_loss: 0.5047
# Epoch 88/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3104 - val_loss: 0.5054
# Epoch 89/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3098 - val_loss: 0.5044
# Epoch 90/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3094 - val_loss: 0.5071
# Epoch 91/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3088 - val_loss: 0.5077
# Epoch 92/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3083 - val_loss: 0.5061
# Epoch 93/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3077 - val_loss: 0.5063
# Epoch 94/100
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.3073 - val_loss: 0.5055
# Epoch 95/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3067 - val_loss: 0.5064
# Epoch 96/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3064 - val_loss: 0.5083
# Epoch 97/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3056 - val_loss: 0.5070
# Epoch 98/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3052 - val_loss: 0.5074
# Epoch 99/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3048 - val_loss: 0.5067
# Epoch 100/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.3043 - val_loss: 0.5076

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(None,))
decoder_state_input_c = Input(shape=(None,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq) ## h and c state

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1. ## \t can use <start also>

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :]) ## Not using Teacher Force 
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or ## can use <end also>
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Va chez chez !
#
# -
# Input sentence: Run!
# Decoded sentence: Courez !
#
# -
# Input sentence: Run!
# Decoded sentence: Courez !
#
# -
# Input sentence: Wow!
# Decoded sentence: Noue avons partir.
#
# -
# Input sentence: Fire!
# Decoded sentence: L'est mourir.
#
# -
# Input sentence: Help!
# Decoded sentence: Pends-toi !
#
# -
# Input sentence: Jump.
# Decoded sentence: Dis chanter.
#
# -
# Input sentence: Stop!
# Decoded sentence: Soyez chez !
#
# -
# Input sentence: Stop!
# Decoded sentence: Soyez chez !
#
# -
# Input sentence: Stop!
# Decoded sentence: Soyez chez !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: I see.
# Decoded sentence: Je connait.
#
# -
# Input sentence: I try.
# Decoded sentence: J'essayer.
#
# -
# Input sentence: I won!
# Decoded sentence: J'ai rendre.
#
# -
# Input sentence: I won!
# Decoded sentence: J'ai rendre.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Oh non !
#
# -
# Input sentence: Attack!
# Decoded sentence: Allez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Allez !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Des !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Des !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Des !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Des !
#
# -
# Input sentence: Get up.
# Decoded sentence: Attrape le chanter ?
#
# -
# Input sentence: Got it!
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Got it!
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Got it?
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Got it?
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Got it?
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Hop in.
# Decoded sentence: Destez !
#
# -
# Input sentence: Hop in.
# Decoded sentence: Destez !
#
# -
# Input sentence: Hug me.
# Decoded sentence: Perrezles-le.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Perrezles-le.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis partir.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis partir.
#
# -
# Input sentence: I know.
# Decoded sentence: Je sais.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partir.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partir.
#
# -
# Input sentence: I lost.
# Decoded sentence: Je le sante.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: J'ai eu de manger.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis chance.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis chance.
#
# -
# Input sentence: Listen.
# Decoded sentence: Diens !
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: No way!
# Decoded sentence: C'est la maison.
#
# -
# Input sentence: Really?
# Decoded sentence: Va chez chez chez !
#
# -
# Input sentence: Really?
# Decoded sentence: Va chez chez chez !
#
# -
# Input sentence: Really?
# Decoded sentence: Va chez chez chez !
#
# -
# Input sentence: Thanks.
# Decoded sentence: Entreste !
#
# -
# Input sentence: We try.
# Decoded sentence: Nous nous avons partir.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons partir.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons partir.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons partir.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons partir.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Comment-il ?
#
# -
# Input sentence: Awesome!
# Decoded sentence: Contez-moi !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez chanter !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez chanter !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez chanter !
#
# -
# Input sentence: Be cool.
# Decoded sentence: Soyez prient.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be kind.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez chans !
#
# -
# Input sentence: Beat it.
# Decoded sentence: Soyez pas.
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-vous !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-vous !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appellez-vous !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appellez-vous !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
#
# -
# Input sentence: Come on!
# Decoded sentence: Arrête !
#
# -
# Input sentence: Come on.
# Decoded sentence: Venez !
#
# -
# Input sentence: Come on.
# Decoded sentence: Venez !
#
# -
# Input sentence: Come on.
# Decoded sentence: Venez !
#
# -
# Input sentence: Drop it!
# Decoded sentence: Laissez-moi la maison.
#
# -
# Input sentence: Drop it!
# Decoded sentence: Laissez-moi la maison.
#
# -
# Input sentence: Drop it!
# Decoded sentence: Laissez-moi la maison.
#
# -
# Input sentence: Drop it!
# Decoded sentence: Laissez-moi la maison.
#
# -
# Input sentence: Get out!
# Decoded sentence: Allez-vous !
#
# -
# Input sentence: Get out!
# Decoded sentence: Allez-vous !
#
# -
# Input sentence: Get out!
# Decoded sentence: Allez-vous !
#
# -
# Input sentence: Get out.
# Decoded sentence: Allez aide.
